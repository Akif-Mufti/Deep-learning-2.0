# %% [markdown]
# <a href="https://colab.research.google.com/github/Akif-Mufti/Deep-learning-2.0/blob/master/matplt_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Learning matplotlib

import matplotlib.pyplot as plt

import numpy as np

# %%
 x = np.linspace(0, 10,10) 

 # ( first point, last pont, how many points in between)

 y =np.sin(x)

 plt.plot(x,y)

# %%
plt.xlabel("time")
plt.ylabel("function of time ")
plt.title("my chart")
plt.plot(x,y)

# %%
x = np.linspace(0, 10,100) 

 # ( plot becmes more smooth with more data points)

y =np.sin(x)

plt.plot(x,y)
plt.show()
