# %% [markdown]
# <a href="https://colab.research.google.com/github/Akif-Mufti/Deep-learning-2.0/blob/master/Scipyfuncs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading matlab file
#scipy.io.loadmat(file_name, mdict=None, appendmat=True, **kwargs)[source]
#audio file
#scipy.io.wavfile.read(filename, mmap=False)

#scipy has many signal processing functions

#fourier transform, converts it from time domain to frequency domain
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(0,100,10000)
y = np.sin(x) + np.sin(3*x) +np.sin(5*x)

plt.plot(y)

# %%
#A fast Fourier transform (FFT)

Y = np.fft.fft(y)

plt.plot(np.abs(Y))
